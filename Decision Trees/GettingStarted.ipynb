# %%
# import pandas
# DS = pandas.read_csv("train.csv")
# print(DS)

# %%
# import pandas
# from sklearn import tree
# from sklearn.tree import DecisionTreeClassifier
# import matplotlib.pyplot as plt

# df = pandas.read_csv("train.csv")

# d = {'male': 0, 'female': 1}
# df['Sex'] = df['Sex'].map(d)
# d = {'1': 0, '2': 1, '3': 2}
# df['Pclass'] = df['Pclass'].map(d)


# features = ['Survived', 'Pclass', 'Sex', 'Age']

# X = df[features]
# y = df['Pclass']

# dtree = DecisionTreeClassifier()
# dtree = dtree.fit(X, y)

# tree.plot_tree(dtree, feature_names=features)

# %%
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

df = pd.read_csv("train.csv")

# Converting male and female into numerical values.
d = {'male': 0, 'female': 1}
df['Sex'] = df['Sex'].map(d)

# Any data that is missing from Age in the dataset will be filled in with a median age of passangers, to prevent missing data
df['Age'].fillna(df['Age'].median(), inplace=True)

# The Pclass, Sex and Age columns will be used for Predicting survival
features = ['Pclass', 'Sex', 'Age']
X = df[features]
y = df['Survived']

dtree = DecisionTreeClassifier(max_depth=3)
dtree.fit(X, y)
plt.figure(figsize=(10, 8))
tree.plot_tree(dtree, feature_names=features, class_names=['Not Survived', 'Survived'], filled=True, fontsize= 10) # Added font size, this allows the tree to be more visable
plt.title("Decision Tree for Titanic Survival Prediction")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Luka Brennan\AppData\Local\Temp\ipykernel_7952\3163661588.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
